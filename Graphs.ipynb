# %%
from RSA2 import RSA
import timeit
from helpers import ConvertToStr

# %%
bits = [128, 256, 512, 1024]
times = []
for bits_number in bits:
    message = "Top secret message with " + str(bits_number) + "bits"
    rsa = RSA(bits_number=bits_number)
    starting_time = timeit.default_timer()
    cipher = rsa.encrypt(message=message)
    ending_time = timeit.default_timer()
    times.append((ending_time - starting_time) * 1000)
    print("message is ", message)
    print("decrypted message is ", ConvertToStr(rsa.decrypt(cipher)))
# Out:
# message is  Top secret message with 128bits
# decrypted message is  Top secret message with 128bits
# message is  Top secret message with 256bits
# decrypted message is  Top secret message with 256bits
# message is  Top secret message with 512bits
# decrypted message is  Top secret message with 512bits
# message is  Top secret message with 1024bits
# decrypted message is  Top secret message with 1024bits

# %%
import matplotlib.pyplot  as plt
plt.figure(figsize=(12, 8))
plt.plot(bits, times)
plt.xlabel("key length", fontsize=18)
plt.ylabel("Encryption time in milliseconds", fontsize=18)
plt.xticks(bits)
plt.title("RSA encryption time vs key length", fontsize=20)
# Out:
# Text(0.5, 1.0, 'RSA encryption time vs key length')
